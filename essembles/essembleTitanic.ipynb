# %%
# !pip install xgboost lightgbm catboost -q

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, mean_squared_error
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
import numpy as np


df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
# Selecionar features
X = df[['Pclass', 'Sex', 'Age', 'Fare']]
y = df['Survived']

# Tratar dados
X['Sex'] = LabelEncoder().fit_transform(X['Sex'])
X['Age'] = SimpleImputer(strategy='median').fit_transform(X[['Age']])

# Dividir
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# /tmp/ipykernel_418415/3152149353.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Sex'] = LabelEncoder().fit_transform(X['Sex'])
# /tmp/ipykernel_418415/3152149353.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Age'] = SimpleImputer(strategy='median').fit_transform(X[['Age']])

# %%
gb_titanic = GradientBoostingClassifier()
gb_titanic.fit(X_train, y_train)
pred = gb_titanic.predict(X_test)

print("\n=== Caso Real: Titanic ===")
print("Accuracy:", accuracy_score(y_test, pred))
print("Recall:", recall_score(y_test, pred))
print("Precision:", precision_score(y_test, pred))
print("F1:", f1_score(y_test, pred))
print("MSE:", mean_squared_error(y_test, pred))
# Out:
# === Caso Real: Titanic ===
# Accuracy: 0.8171641791044776
# Recall: 0.6576576576576577
# Precision: 0.8690476190476191
# F1: 0.7487179487179487
# MSE: 0.1828358208955224
